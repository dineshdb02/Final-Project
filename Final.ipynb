# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshdb02/Final-Project/blob/main/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
store_data= pd.read_csv('/content/stores_data_set.csv')
feature_data= pd.read_csv('/content/Features_data_set.csv')
sales_data= pd.read_csv('/content/sales_data_set.csv')

# %%
sales_data.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  05/02/2010      24924.50      False
# 1      1     1  12/02/2010      46039.49       True
# 2      1     1  19/02/2010      41595.55      False
# 3      1     1  26/02/2010      19403.54      False
# 4      1     1  05/03/2010      21827.90      False

# %%
sales_data.shape
# Out:
# (421570, 5)

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
sales_data.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
sales_data.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
sales_data.duplicated().sum()
# Out:
# 0

# %%
sales_data.nunique()
# Out:
# Store               45
# Dept                81
# Date               143
# Weekly_Sales    359464
# IsHoliday            2
# dtype: int64

# %%
feature_data.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        NaN        NaN
# 1      1  12/02/2010        38.51       2.548        NaN        NaN
# 2      1  19/02/2010        39.93       2.514        NaN        NaN
# 3      1  26/02/2010        46.63       2.561        NaN        NaN
# 4      1  05/03/2010        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
feature_data.shape
# Out:
# (8190, 12)

# %%
feature_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
feature_data.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
feature_data.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
feature_data.duplicated().sum()
# Out:
# 0

# %%
feature_data.nunique()
# Out:
# Store             45
# Date             182
# Temperature     4178
# Fuel_Price      1011
# MarkDown1       4023
# MarkDown2       2715
# MarkDown3       2885
# MarkDown4       3405
# MarkDown5       4045
# CPI             2505
# Unemployment     404
# IsHoliday          2
# dtype: int64

# %%
store_data.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
store_data.shape
# Out:
# (45, 3)

# %%
store_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
store_data.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
store_data.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
store_data.duplicated().sum()
# Out:
# 0

# %%
store_data.nunique()
# Out:
# Store    45
# Type      3
# Size     40
# dtype: int64

# %%
store_data['Type'].value_counts()
# Out:
# Type
# A    22
# B    17
# C     6
# Name: count, dtype: int64

# %%
sales_data["Store"].value_counts()
# Out:
# Store
# 13    10474
# 10    10315
# 4     10272
# 1     10244
# 2     10238
# 24    10228
# 27    10225
# 34    10224
# 20    10214
# 6     10211
# 32    10202
# 19    10148
# 31    10142
# 28    10113
# 41    10088
# 11    10062
# 23    10050
# 14    10040
# 40    10017
# 15     9901
# 8      9895
# 39     9878
# 17     9864
# 18     9859
# 26     9854
# 25     9804
# 7      9762
# 12     9705
# 22     9688
# 45     9637
# 21     9582
# 35     9528
# 29     9455
# 16     9443
# 3      9036
# 5      8999
# 9      8867
# 38     7362
# 37     7206
# 44     7169
# 30     7156
# 42     6953
# 43     6751
# 33     6487
# 36     6222
# Name: count, dtype: int64

# %%
sales_data
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
store_data
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
feature_data
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
df1=pd.concat([sales_data,store_data,feature_data],axis=1)
df1
# Out:
#         Store  Dept        Date  Weekly_Sales IsHoliday  Store Type      Size  \
# 0           1     1  05/02/2010      24924.50     False    1.0    A  151315.0
# 1           1     1  12/02/2010      46039.49      True    2.0    A  202307.0
# 2           1     1  19/02/2010      41595.55     False    3.0    B   37392.0
# 3           1     1  26/02/2010      19403.54     False    4.0    A  205863.0
# 4           1     1  05/03/2010      21827.90     False    5.0    B   34875.0
# ...       ...   ...         ...           ...       ...    ...  ...       ...
# 421565     45    98  28/09/2012        508.37     False    NaN  NaN       NaN
# 421566     45    98  05/10/2012        628.10     False    NaN  NaN       NaN
# 421567     45    98  12/10/2012       1061.02     False    NaN  NaN       NaN
# 421568     45    98  19/10/2012        760.01     False    NaN  NaN       NaN
# 421569     45    98  26/10/2012       1076.80     False    NaN  NaN       NaN
#
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1.0  05/02/2010        42.31       2.572        NaN        NaN
# 1         1.0  12/02/2010        38.51       2.548        NaN        NaN
# 2         1.0  19/02/2010        39.93       2.514        NaN        NaN
# 3         1.0  26/02/2010        46.63       2.561        NaN        NaN
# 4         1.0  05/03/2010        46.50       2.625        NaN        NaN
# ...       ...         ...          ...         ...        ...        ...
# 421565    NaN         NaN          NaN         NaN        NaN        NaN
# 421566    NaN         NaN          NaN         NaN        NaN        NaN
# 421567    NaN         NaN          NaN         NaN        NaN        NaN
# 421568    NaN         NaN          NaN         NaN        NaN        NaN
# 421569    NaN         NaN          NaN         NaN        NaN        NaN
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0             NaN        NaN        NaN  211.096358         8.106     False
# 1             NaN        NaN        NaN  211.242170         8.106      True
# 2             NaN        NaN        NaN  211.289143         8.106     False
# 3             NaN        NaN        NaN  211.319643         8.106     False
# 4             NaN        NaN        NaN  211.350143         8.106     False
# ...           ...        ...        ...         ...           ...       ...
# 421565        NaN        NaN        NaN         NaN           NaN       NaN
# 421566        NaN        NaN        NaN         NaN           NaN       NaN
# 421567        NaN        NaN        NaN         NaN           NaN       NaN
# 421568        NaN        NaN        NaN         NaN           NaN       NaN
# 421569        NaN        NaN        NaN         NaN           NaN       NaN
#
# [421570 rows x 20 columns]

# %%
df.shape
# Out:
# (421570, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Store         45 non-null      float64
#  6   Type          45 non-null      object
#  7   Size          45 non-null      float64
#  8   Store         8190 non-null    float64
#  9   Date          8190 non-null    object
#  10  Temperature   8190 non-null    float64
#  11  Fuel_Price    8190 non-null    float64
#  12  MarkDown1     4032 non-null    float64
#  13  MarkDown2     2921 non-null    float64
#  14  MarkDown3     3613 non-null    float64
#  15  MarkDown4     3464 non-null    float64
#  16  MarkDown5     4050 non-null    float64
#  17  CPI           7605 non-null    float64
#  18  Unemployment  7605 non-null    float64
#  19  IsHoliday     8190 non-null    object
# dtypes: bool(1), float64(13), int64(2), object(4)
# memory usage: 61.5+ MB

# %%
df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# Type            0
# Size            0
# dtype: int64

# %%
df=pd.merge(sales_data,store_data,on='Store')
df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size
# 0           1     1  05/02/2010      24924.50      False    A  151315
# 1           1     1  12/02/2010      46039.49       True    A  151315
# 2           1     1  19/02/2010      41595.55      False    A  151315
# 3           1     1  26/02/2010      19403.54      False    A  151315
# 4           1     1  05/03/2010      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  28/09/2012        508.37      False    B  118221
# 421566     45    98  05/10/2012        628.10      False    B  118221
# 421567     45    98  12/10/2012       1061.02      False    B  118221
# 421568     45    98  19/10/2012        760.01      False    B  118221
# 421569     45    98  26/10/2012       1076.80      False    B  118221
#
# [421570 rows x 7 columns]

# %%
di=pd.merge(df,feature_data,on=['Store', 'Date'],how='inner')
di
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 0           1     1  05/02/2010      24924.50        False    A  151315
# 1           1     2  05/02/2010      50605.27        False    A  151315
# 2           1     3  05/02/2010      13740.12        False    A  151315
# 3           1     4  05/02/2010      39954.04        False    A  151315
# 4           1     5  05/02/2010      32229.38        False    A  151315
# ...       ...   ...         ...           ...          ...  ...     ...
# 421565     45    93  26/10/2012       2487.80        False    B  118221
# 421566     45    94  26/10/2012       5203.31        False    B  118221
# 421567     45    95  26/10/2012      56017.47        False    B  118221
# 421568     45    97  26/10/2012       6817.48        False    B  118221
# 421569     45    98  26/10/2012       1076.80        False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             42.31       2.572        NaN        NaN        NaN        NaN
# 2             42.31       2.572        NaN        NaN        NaN        NaN
# 3             42.31       2.572        NaN        NaN        NaN        NaN
# 4             42.31       2.572        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 421565        58.85       3.882    4018.91      58.08      100.0     211.94
# 421566        58.85       3.882    4018.91      58.08      100.0     211.94
# 421567        58.85       3.882    4018.91      58.08      100.0     211.94
# 421568        58.85       3.882    4018.91      58.08      100.0     211.94
# 421569        58.85       3.882    4018.91      58.08      100.0     211.94
#
#         MarkDown5         CPI  Unemployment  IsHoliday_y
# 0             NaN  211.096358         8.106        False
# 1             NaN  211.096358         8.106        False
# 2             NaN  211.096358         8.106        False
# 3             NaN  211.096358         8.106        False
# 4             NaN  211.096358         8.106        False
# ...           ...         ...           ...          ...
# 421565     858.33  192.308899         8.667        False
# 421566     858.33  192.308899         8.667        False
# 421567     858.33  192.308899         8.667        False
# 421568     858.33  192.308899         8.667        False
# 421569     858.33  192.308899         8.667        False
#
# [421570 rows x 17 columns]

# %%
di.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday_x   421570 non-null  bool
#  5   Type          421570 non-null  object
#  6   Size          421570 non-null  int64
#  7   Temperature   421570 non-null  float64
#  8   Fuel_Price    421570 non-null  float64
#  9   MarkDown1     150681 non-null  float64
#  10  MarkDown2     111248 non-null  float64
#  11  MarkDown3     137091 non-null  float64
#  12  MarkDown4     134967 non-null  float64
#  13  MarkDown5     151432 non-null  float64
#  14  CPI           421570 non-null  float64
#  15  Unemployment  421570 non-null  float64
#  16  IsHoliday_y   421570 non-null  bool
# dtypes: bool(2), float64(10), int64(3), object(2)
# memory usage: 49.0+ MB

# %%
di.Date=pd.to_datetime(di.Date, format="%d/%m/%Y")

# %%
di
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday_x Type    Size  \
# 0           1     1 2010-02-05      24924.50        False    A  151315
# 1           1     2 2010-02-05      50605.27        False    A  151315
# 2           1     3 2010-02-05      13740.12        False    A  151315
# 3           1     4 2010-02-05      39954.04        False    A  151315
# 4           1     5 2010-02-05      32229.38        False    A  151315
# ...       ...   ...        ...           ...          ...  ...     ...
# 421565     45    93 2012-10-26       2487.80        False    B  118221
# 421566     45    94 2012-10-26       5203.31        False    B  118221
# 421567     45    95 2012-10-26      56017.47        False    B  118221
# 421568     45    97 2012-10-26       6817.48        False    B  118221
# 421569     45    98 2012-10-26       1076.80        False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             42.31       2.572        NaN        NaN        NaN        NaN
# 2             42.31       2.572        NaN        NaN        NaN        NaN
# 3             42.31       2.572        NaN        NaN        NaN        NaN
# 4             42.31       2.572        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 421565        58.85       3.882    4018.91      58.08      100.0     211.94
# 421566        58.85       3.882    4018.91      58.08      100.0     211.94
# 421567        58.85       3.882    4018.91      58.08      100.0     211.94
# 421568        58.85       3.882    4018.91      58.08      100.0     211.94
# 421569        58.85       3.882    4018.91      58.08      100.0     211.94
#
#         MarkDown5         CPI  Unemployment  IsHoliday_y
# 0             NaN  211.096358         8.106        False
# 1             NaN  211.096358         8.106        False
# 2             NaN  211.096358         8.106        False
# 3             NaN  211.096358         8.106        False
# 4             NaN  211.096358         8.106        False
# ...           ...         ...           ...          ...
# 421565     858.33  192.308899         8.667        False
# 421566     858.33  192.308899         8.667        False
# 421567     858.33  192.308899         8.667        False
# 421568     858.33  192.308899         8.667        False
# 421569     858.33  192.308899         8.667        False
#
# [421570 rows x 17 columns]

# %%
di.nunique()
# Out:
# Store               45
# Dept                81
# Date               143
# Weekly_Sales    359464
# IsHoliday_x          2
# Type                 3
# Size                40
# Temperature       3528
# Fuel_Price         892
# MarkDown1         2277
# MarkDown2         1499
# MarkDown3         1662
# MarkDown4         1944
# MarkDown5         2293
# CPI               2145
# Unemployment       349
# IsHoliday_y          2
# dtype: int64

# %%
cat_col=['Store',"Dept","Type","IsHoliday","Size"]
continuous_col=['Temperature','Fuel_Price','CPI','Unemployment',"Weekly_Sales","MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"]
df_numeric=di.select_dtypes(include=np.number)

# %%
di.duplicated().sum()
# Out:
# 0

# %%
di.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# IsHoliday_x               bool
# Type                    object
# Size                     int64
# Temperature            float64
# Fuel_Price             float64
# MarkDown1              float64
# MarkDown2              float64
# MarkDown3              float64
# MarkDown4              float64
# MarkDown5              float64
# CPI                    float64
# Unemployment           float64
# IsHoliday_y               bool
# dtype: object

# %%
di.select_dtypes(include='object')
# Out:
#        Type
# 0         A
# 1         A
# 2         A
# 3         A
# 4         A
# ...     ...
# 421565    B
# 421566    B
# 421567    B
# 421568    B
# 421569    B
#
# [421570 rows x 1 columns]

# %%
df_numeric.corr()
# Out:
#                  Store      Dept  Weekly_Sales      Size  Temperature  \
# Store         1.000000  0.024004     -0.085195 -0.182881    -0.050097
# Dept          0.024004  1.000000      0.148032 -0.002966     0.004437
# Weekly_Sales -0.085195  0.148032      1.000000  0.243828    -0.002312
# Size         -0.182881 -0.002966      0.243828  1.000000    -0.058313
# Temperature  -0.050097  0.004437     -0.002312 -0.058313     1.000000
# Fuel_Price    0.065290  0.003572     -0.000120  0.003361     0.143859
# MarkDown1    -0.119588 -0.002426      0.085251  0.345673    -0.040594
# MarkDown2    -0.035173  0.000290      0.024130  0.108827    -0.323927
# MarkDown3    -0.031556  0.001784      0.060385  0.048913    -0.096880
# MarkDown4    -0.009941  0.004257      0.045414  0.168196    -0.063947
# MarkDown5    -0.026634  0.000109      0.090362  0.304575    -0.017544
# CPI          -0.211088 -0.007477     -0.020921 -0.003314     0.182112
# Unemployment  0.208552  0.007837     -0.025864 -0.068238     0.096730
#
#               Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# Store           0.065290  -0.119588  -0.035173  -0.031556  -0.009941
# Dept            0.003572  -0.002426   0.000290   0.001784   0.004257
# Weekly_Sales   -0.000120   0.085251   0.024130   0.060385   0.045414
# Size            0.003361   0.345673   0.108827   0.048913   0.168196
# Temperature     0.143859  -0.040594  -0.323927  -0.096880  -0.063947
# Fuel_Price      1.000000   0.061371  -0.220895  -0.102092  -0.044986
# MarkDown1       0.061371   1.000000   0.024486  -0.108115   0.819238
# MarkDown2      -0.220895   0.024486   1.000000  -0.050108  -0.007768
# MarkDown3      -0.102092  -0.108115  -0.050108   1.000000  -0.071095
# MarkDown4      -0.044986   0.819238  -0.007768  -0.071095   1.000000
# MarkDown5      -0.128065   0.160257  -0.007440  -0.026467   0.107792
# CPI            -0.164210  -0.055558  -0.039534  -0.023590  -0.049628
# Unemployment   -0.033853   0.050285   0.020940   0.012818   0.024963
#
#               MarkDown5       CPI  Unemployment
# Store         -0.026634 -0.211088      0.208552
# Dept           0.000109 -0.007477      0.007837
# Weekly_Sales   0.090362 -0.020921     -0.025864
# Size           0.304575 -0.003314     -0.068238
# Temperature   -0.017544  0.182112      0.096730
# Fuel_Price    -0.128065 -0.164210     -0.033853
# MarkDown1      0.160257 -0.055558      0.050285
# MarkDown2     -0.007440 -0.039534      0.020940
# MarkDown3     -0.026467 -0.023590      0.012818
# MarkDown4      0.107792 -0.049628      0.024963
# MarkDown5      1.000000  0.060630     -0.003843
# CPI            0.060630  1.000000     -0.299953
# Unemployment  -0.003843 -0.299953      1.000000

# %%
di.IsHoliday_x.value_counts()
# Out:
# IsHoliday_x
# False    391909
# True      29661
# Name: count, dtype: int64

# %%
di.IsHoliday_y.value_counts()
# Out:
# IsHoliday_y
# False    391909
# True      29661
# Name: count, dtype: int64

# %%
di.drop(['IsHoliday_x'],axis=1,inplace=True)

# %%
di.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# Type                 0
# Size                 0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# IsHoliday_y          0
# dtype: int64

# %%
# db=di.copy()
di.fillna(0,inplace=True)

# %%
di.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# Type            0
# Size            0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# IsHoliday_y     0
# dtype: int64

# %%
di.Date=pd.to_datetime(di.Date, format="%d/%m/%Y")
di["day"]=di.Date.dt.day
di["month"]=di.Date.dt.month
di["year"]=di.Date.dt.year

# %%
db["Date"]=pd.to_datetime(db.Date,format="%d/%m/%Y")
db["day"]=db.Date.dt.day
db["month"]=db.Date.dt.month
db["year"]=db.Date.dt.year

# %%
di.drop(columns=['Date'],inplace=True)

# %%
di
# Out:
#         Store  Dept  Weekly_Sales Type    Size  Temperature  Fuel_Price  \
# 0           1     1      24924.50    A  151315        42.31       2.572
# 1           1     2      50605.27    A  151315        42.31       2.572
# 2           1     3      13740.12    A  151315        42.31       2.572
# 3           1     4      39954.04    A  151315        42.31       2.572
# 4           1     5      32229.38    A  151315        42.31       2.572
# ...       ...   ...           ...  ...     ...          ...         ...
# 421565     45    93       2487.80    B  118221        58.85       3.882
# 421566     45    94       5203.31    B  118221        58.85       3.882
# 421567     45    95      56017.47    B  118221        58.85       3.882
# 421568     45    97       6817.48    B  118221        58.85       3.882
# 421569     45    98       1076.80    B  118221        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0            0.00       0.00        0.0       0.00       0.00  211.096358
# 1            0.00       0.00        0.0       0.00       0.00  211.096358
# 2            0.00       0.00        0.0       0.00       0.00  211.096358
# 3            0.00       0.00        0.0       0.00       0.00  211.096358
# 4            0.00       0.00        0.0       0.00       0.00  211.096358
# ...           ...        ...        ...        ...        ...         ...
# 421565    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421566    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421567    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421568    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421569    4018.91      58.08      100.0     211.94     858.33  192.308899
#
#         Unemployment  IsHoliday_y  day  month  year
# 0              8.106        False    5      2  2010
# 1              8.106        False    5      2  2010
# 2              8.106        False    5      2  2010
# 3              8.106        False    5      2  2010
# 4              8.106        False    5      2  2010
# ...              ...          ...  ...    ...   ...
# 421565         8.667        False   26     10  2012
# 421566         8.667        False   26     10  2012
# 421567         8.667        False   26     10  2012
# 421568         8.667        False   26     10  2012
# 421569         8.667        False   26     10  2012
#
# [421570 rows x 18 columns]

# %% [markdown]
# ***outliers***

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
for i in continuous_col:
  plt.figure()
  sns.boxplot(di[i])
  plt.show()

# %%
sns.boxplot(db['Weekly_Sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
upper_limit=db["Weekly_Sales"].mean()+3*db["Weekly_Sales"].std()
lower_limit=db["Weekly_Sales"].mean()-3*db["Weekly_Sales"].std()
print(upper_limit)
print(lower_limit)
# Out:
# 84114.80868095672
# -52152.292434022645

# %%
#removing outliers
din=db.loc[(db["Weekly_Sales"]<upper_limit)&(db["Weekly_Sales"]> lower_limit)]
print(len(db)-len(din))
print(len(din))
print(len(db))
# Out:
# 8848
# 412722
# 421570

# %%
sns.boxplot(din['Weekly_Sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def iqr(df,col):
  q1=df[col].quantile(0.25)
  q3=df[col].quantile(0.75)
  iqr=q3-q1
  upper_limit=q3+1.5*iqr
  lower_limit=q1-1.5*iqr
  return upper_limit,lower_limit
  # sns.boxplot(df[col])
  # plt.show
  # di.loc[df[col] > upper_limit, col] = upper_limit
  # di.loc[df[col] < lower_limit, col] = lower_limit
  # sns.boxplot(df[col])
  # plt.show

# q1=di['Weekly_Sales'].quantile(0.25)
# q3=di['Weekly_Sales'].quantile(0.75)
# iqr=q3-q1
# upper_limit=q3+1.5*iqr
# lower_limit=q1-1.5*iqr

# %%
iqr(di,'Weekly_Sales')
# Out:
# (47395.15625, -25109.653749999998)

# %%
sns.boxplot(di['Weekly_Sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
q1=di['Weekly_Sales'].quantile(0.25)
q3=di['Weekly_Sales'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

# %%
di.loc[di['Weekly_Sales'] > upper_limit, 'Weekly_Sales'] = upper_limit
di.loc[di['Weekly_Sales'] < lower_limit, 'Weekly_Sales'] = lower_limit

# %%
di.loc[di['Weekly_Sales'] > upper_limit, 'Weekly_Sales'] = upper_limit
di.loc[di['Weekly_Sales'] < lower_limit, 'Weekly_Sales'] = lower_limit

# %%
sns.boxplot(di['Weekly_Sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def plot(df,col):
  fig,ax=plt.subplots(1,2)
  sns.distplot(df[col],ax=ax[0])
  sns.boxplot(df[col],ax=ax[1])
  plt.show()

# %%
plot(di,'Weekly_Sales')
# Out:
# <ipython-input-33-5dd1b75d4e3e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col],ax=ax[0])

# %%
plot(db,'Weekly_Sales')
# Out:
# <ipython-input-94-5dd1b75d4e3e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col],ax=ax[0])

# %%
pip install Lazy
